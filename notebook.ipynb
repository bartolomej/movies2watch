# %% [markdown]
# # Movie recommendation system

# %%
from backend.src.nmf import NMF
import numpy as np

m = 100       # number of rows
n = 80        # number of columns
rank = 5      # model rank
error = 0.1   # error
A = np.random.rand(m, rank*2)
B = np.random.rand(n, rank*2)
X = A.dot(B.T) + error * np.random.rand(m, n)  # generate random dataset

model = NMF(rank=rank, max_iter=20, eta=0.001)
model.fit(X, verbose=True)
# Out:
# 0 21113.505610556564
# 1 21113.505610556564
# 2 21113.505610556564
# 3 21113.505610556564
# 4 21113.505610556564
# 5 21113.505610556564
# 6 21113.505610556564
# 7 21113.505610556564
# 8 21113.505610556564
# 9 21113.505610556564
# 10 21113.505610556564
# 11 21113.505610556564
# 12 21113.505610556564
# 13 21113.505610556564
# 14 21113.505610556564
# 15 21113.505610556564
# 16 21113.505610556564
# 17 21113.505610556564
# 18 21113.505610556564
# 19 21113.505610556564

# %% [markdown]
# Model error across iterations:

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.plot(model.error)
plt.xlabel("Iteration")
plt.ylabel("Objective function")
# Out:
# Text(0, 0.5, 'Objective function')

# %% [markdown]
# Comparison of the model vs original dataset matrix:

# %%
fig, ax = plt.subplots(nrows=1, ncols=2)
ax[0].pcolor(X)
ax[0].set_title("Original")

ax[1].pcolor(model.predict_all())
ax[1].set_title("Model")
plt.show()

# %% [markdown]
# Explained variance:

# %%
Xp = model.predict_all()
expl_var = (np.var(X) - np.var(X-Xp))/np.var(X)
expl_var
# Out:
# -0.4094236051474014
